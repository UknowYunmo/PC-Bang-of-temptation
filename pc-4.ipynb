# %%
import json
import requests
import sys

url = "https://dapi.kakao.com/v2/local/search/keyword.json?"
apikey = "ccf9c4dda0eed674c075b234b8d3d390"
loc=['중곡동','능동','구의동','광장동','자양동','화양동','군자동'] # 광진구
#loc=['능동'] # 지도 실험용
for k in loc:
    checker=False
    cnt=0
    pc_list=[]
    place_list=[]
    x_list=[]
    y_list=[]
    phone_list=[]
    id_list=[]
    print('-------------------------------'+str(k)+'----------------------------------')
    print()
    query = k+"pc방"
    for i in range(1,46):
        if checker==True:
            break
        cnt+=1
        r = requests.get( url, params = {'page':str(i), 'query':query}, headers={'Authorization' : 'KakaoAK ' + apikey } ).text
        r = json.loads(str(r))
        match_first = r['documents']
        for j in match_first :
            if j['id'] in id_list:
                checker=True
                break
            if k in j['address_name'] :
                pc_list.append(j['place_name'])
                place_list.append(j['address_name'])
                x_list.append(j['x'])
                y_list.append(j['y'])
                phone_list.append(j['phone'])
                id_list.append(j['id'])
    print(pc_list)
    print(place_list)
    print(x_list)
    print(y_list)
    print(phone_list)
    print(len(pc_list))
# Out:
# -------------------------------중곡동----------------------------------
#
# ['세븐PC방', '나인PC', '1프로아레나PC방', '루미너스PC', '라이온PC', '쓰리팝PC카페', '고스트캐슬PC방 중곡점', '고릴라PC방 중곡점', '시엘PC존 중곡점', '제노PC존', '시즌아이PC카페', '오지구지리는PC방', '티라미수PC방 중곡점', '루트PC존', '타짜PC']
# ['서울 광진구 중곡동 648-14', '서울 광진구 중곡동 40-14', '서울 광진구 중곡동 113-7', '서울 광진구 중곡동 164-1', '서울 광진구 중곡동 649-13', '서울 광진구 중곡동 80-11', '서울 광진구 중곡동 92-47', '서울 광진구 중곡동 199-1', '서울 광진구 중곡동 40-2', '서울 광진구 중곡동 113-7', '서울 광진구 중곡동 164-1', '서울 광진구 중곡동 109-4', '서울 광진구 중곡동 170-25', '서울 광진구 중곡동 199-3', '서울 광진구 중곡동 245-1']
# ['127.079578468244', '127.082667208808', '127.091163955464', '127.082323629946', '127.079070204776', '127.088235324981', '127.088411928343', '127.083366353687', '127.08267398888', '127.091124400921', '127.082319054984', '127.092976918201', '127.0823991681', '127.083257220585', '127.079573441161']
# ['37.5581659658391', '37.5623796070274', '37.5531210138308', '37.5628339492355', '37.5580744056177', '37.5571335781662', '37.5562171319256', '37.5702078674007', '37.5623696913201', '37.5531660942488', '37.5627907046042', '37.5549288032407', '37.567703779386', '37.5697898826552', '37.5630169350989']
# ['', '', '', '', '', '', '1588-9253', '070-8885-2311', '', '', '', '', '', '', '']
# 15
# -------------------------------능동----------------------------------
#
# ['샹떼PC방 화성능동점', '아칸PC존', '헌터PC 동탄능동점', '아이센스리그PC방', '피코PC방', '콜로니클 VR방', '풀타임PC방 능동점', '풀타임피시방 능동점', '포시즌PC방', '아이플리PC방']
# ['경기 화성시 능동 1093-13', '경기 화성시 능동 1152-4', '경기 화성시 능동 1064-5', '경기 화성시 능동 1114-6', '경기 화성시 능동 1063-1', '경기 화성시 능동 1113-1', '경기 화성시 능동 1066-3', '경기 화성시 능동 1066-3', '경기 화성시 능동 1064-5', '경기 화성시 능동 1114-6']
5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
import json
import requests
import sys
import folium
m = folium.Map(location=[37.5385583136667, 127.082385189457],zoom_start=13) # 광진구 지도

url = "https://dapi.kakao.com/v2/local/search/keyword.json?"
apikey = "ccf9c4dda0eed674c075b234b8d3d390"
loc=['중곡동','능동','구의동','광장동','자양동','화양동','군자동'] # 광진구
#loc=['능동'] # 지도 실험용
for k in loc:
    checker=False
    cnt=0
    pc_list=[]
    place_list=[]
    x_list=[]
    y_list=[]
    phone_list=[]
    id_list=[]
    print('-------------------------------'+str(k)+'----------------------------------')
    print()
    query = k+"pc방"
    for i in range(1,46):
        if checker==True:
            break
        cnt+=1
        r = requests.get( url, params = {'page':str(i), 'query':query}, headers={'Authorization' : 'KakaoAK ' + apikey } ).text
        r = json.loads(str(r))
        match_first = r['documents']
        for j in match_first :
            if j['id'] in id_list:
                checker=True
                break
            if k in j['address_name'] :
                pc_list.append(j['place_name'])
                place_list.append(j['address_name'])
                x_list.append(j['x'])
                y_list.append(j['y'])
                phone_list.append(j['phone'])
                id_list.append(j['id'])
    for i in range(len(x_list)):
        folium.Marker(location=[y_list[i],x_list[i]],
                      icon=(folium.Icon(icon="gamepad", prefix="fa", color="lightgray")),
                      popup=pc_list[i]).add_to(m)
m
# Out:
# -------------------------------중곡동----------------------------------
#
# -------------------------------능동----------------------------------
#
# -------------------------------구의동----------------------------------
#
# -------------------------------광장동----------------------------------
#
# -------------------------------자양동----------------------------------
#
# -------------------------------화양동----------------------------------
#
# -------------------------------군자동----------------------------------
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_c0a156851aa34d46ae3614134e08bb84%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_c0a156851aa34d46ae3614134e08bb84%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_c0a156851aa34d46ae3614134e08bb84%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_c0a156851aa34d46ae3614134e08bb84%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.5385583136667%2C%20127.082385189457%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
import json
import requests
import sys
import folium
m = folium.Map(location=[37.5385583136667, 127.082385189457],zoom_start=13) # 광진구 지도

url = "https://dapi.kakao.com/v2/local/search/keyword.json?"
apikey = "ccf9c4dda0eed674c075b234b8d3d390"
loc=['중곡동','능동','구의동','광장동','자양동','화양동','군자동'] # 광진구
#loc=['능동'] # 지도 실험용
for k in loc:
    checker=False
    cnt=0
    pc_list=[]
    place_list=[]
    x_list=[]
    y_list=[]
    phone_list=[]
    id_list=[]
    print('-------------------------------'+str(k)+'----------------------------------')
    print()
    query = k+"학교"
    for i in range(1,46):
        if checker==True:
            break
        cnt+=1
        r = requests.get( url, params = {'page':str(i), 'query':query}, headers={'Authorization' : 'KakaoAK ' + apikey } ).text
        r = json.loads(str(r))
        match_first = r['documents']
        for j in match_first :
            if j['id'] in id_list:
                checker=True
                break
            if j['category_name'][13:14] in ['중','고']:
                if k in j['address_name'] :
                    pc_list.append(j['place_name'])
                    place_list.append(j['address_name'])
                    x_list.append(j['x'])
                    y_list.append(j['y'])
                    phone_list.append(j['phone'])
                    id_list.append(j['id'])
    for i in range(len(x_list)):
        folium.Marker(location=[y_list[i],x_list[i]],
                      icon=(folium.Icon(icon="male", prefix="fa", color="red")),
                      popup=pc_list[i],max_width='40').add_to(m)
m
# Out:
# -------------------------------중곡동----------------------------------
#
# -------------------------------능동----------------------------------
#
# -------------------------------구의동----------------------------------
#
# -------------------------------광장동----------------------------------
#
# -------------------------------자양동----------------------------------
#
# -------------------------------화양동----------------------------------
#
# -------------------------------군자동----------------------------------
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_b4dff0b8c9a24a3aaafe61586a816199%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_b4dff0b8c9a24a3aaafe61586a816199%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_b4dff0b8c9a24a3aaafe61586a816199%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_b4dff0b8c9a24a3aaafe61586a816199%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.5385583136667%2C%20127.082385189457%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
import json
import requests
import sys
import folium
m = folium.Map(location=[37.5385583136667, 127.082385189457],zoom_start=13) # 광진구 지도

url = "https://dapi.kakao.com/v2/local/search/keyword.json?"
apikey = "ccf9c4dda0eed674c075b234b8d3d390"
loc=['중곡동','능동','구의동','광장동','자양동','화양동','군자동'] # 광진구
#loc=['능동'] # 지도 실험용
for k in loc:
    checker=False
    cnt=0
    pc_list=[]
    place_list=[]
    x_list=[]
    y_list=[]
    phone_list=[]
    id_list=[]
    print('-------------------------------'+str(k)+'----------------------------------')
    print()
    query = k+"pc방"
    for i in range(1,46):
        if checker==True:
            break
        cnt+=1
        r = requests.get( url, params = {'page':str(i), 'query':query}, headers={'Authorization' : 'KakaoAK ' + apikey } ).text
        r = json.loads(str(r))
        match_first = r['documents']
        for j in match_first :
            if j['id'] in id_list:
                checker=True
                break
            if k in j['address_name'] :
                pc_list.append(j['place_name'])
                place_list.append(j['address_name'])
                x_list.append(j['x'])
                y_list.append(j['y'])
                phone_list.append(j['phone'])
                id_list.append(j['id'])
    for i in range(len(x_list)):
        folium.Marker(location=[y_list[i],x_list[i]],
                      icon=(folium.Icon(icon="gamepad", prefix="fa", color="lightgray")),
                      popup=pc_list[i]).add_to(m)
for k in loc:
    checker=False
    cnt=0
    pc_list=[]
    place_list=[]
    x_list=[]
    y_list=[]
    phone_list=[]
    id_list=[]
    print('-------------------------------'+str(k)+'----------------------------------')
    print()
    query = k+"학교"
    for i in range(1,46):
        if checker==True:
            break
        cnt+=1
        r = requests.get( url, params = {'page':str(i), 'query':query}, headers={'Authorization' : 'KakaoAK ' + apikey } ).text
        r = json.loads(str(r))
        match_first = r['documents']
        for j in match_first :
            if j['id'] in id_list:
                checker=True
                break
            if j['category_name'][13:14] in ['중','고']:
                if k in j['address_name'] :
                    pc_list.append(j['place_name'])
                    place_list.append(j['address_name'])
                    x_list.append(j['x'])
                    y_list.append(j['y'])
                    phone_list.append(j['phone'])
                    id_list.append(j['id'])
    for i in range(len(x_list)):
        folium.Marker(location=[y_list[i],x_list[i]],
                      icon=(folium.Icon(icon="male", prefix="fa", color="red")),
                      popup=pc_list[i],max_width='40').add_to(m)
m
# Out:
# -------------------------------중곡동----------------------------------
#
# -------------------------------능동----------------------------------
#
# -------------------------------구의동----------------------------------
#
# -------------------------------광장동----------------------------------
#
# -------------------------------자양동----------------------------------
#
# -------------------------------화양동----------------------------------
#
# -------------------------------군자동----------------------------------
#
# -------------------------------중곡동----------------------------------
#
# -------------------------------능동----------------------------------
#
# -------------------------------구의동----------------------------------
#
# -------------------------------광장동----------------------------------
#
# -------------------------------자양동----------------------------------
#
# -------------------------------화양동----------------------------------
#
# -------------------------------군자동----------------------------------
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_a010ba89d96043579dc3a9ee803477d5%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_a010ba89d96043579dc3a9ee803477d5%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_a010ba89d96043579dc3a9ee803477d5%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_a010ba89d96043579dc3a9ee803477d5%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.5385583136667%2C%20127.082385189457%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
import json
import requests
import sys
import folium
m = folium.Map(location=[37.5385583136667, 127.082385189457],zoom_start=13) # 광진구 지도

url = "https://dapi.kakao.com/v2/local/search/keyword.json?"
apikey = "ccf9c4dda0eed674c075b234b8d3d390"
loc=['중곡동','능동','구의동','광장동','자양동','화양동','군자동'] # 광진구
#loc=['능동'] # 지도 실험용
for k in loc:
    checker=False
    cnt=0
    pc_list=[]
    place_list=[]
    x_list=[]
    y_list=[]
    phone_list=[]
    id_list=[]
    print('-------------------------------'+str(k)+'----------------------------------')
    print()
    query = k+" 독서실"
    for i in range(1,46):
        if checker==True:
            break
        cnt+=1
        r = requests.get( url, params = {'page':str(i), 'query':query}, headers={'Authorization' : 'KakaoAK ' + apikey } ).text
        r = json.loads(str(r))
        match_first = r['documents']
        for j in match_first :
            if j['id'] in id_list:
                checker=True
                break
            if k in j['address_name'] :
                pc_list.append(j['place_name'])
                place_list.append(j['address_name'])
                x_list.append(j['x'])
                y_list.append(j['y'])
                phone_list.append(j['phone'])
                id_list.append(j['id'])
    for i in range(len(x_list)):
        folium.Marker(location=[y_list[i],x_list[i]],
                      icon=(folium.Icon(icon="book", prefix="fa", color="lightblue")),
                      popup=pc_list[i],max_width='40').add_to(m)
m
# Out:
# -------------------------------중곡동----------------------------------
#
# -------------------------------능동----------------------------------
#
# -------------------------------구의동----------------------------------
#
# -------------------------------광장동----------------------------------
#
# -------------------------------자양동----------------------------------
#
# -------------------------------화양동----------------------------------
#
# -------------------------------군자동----------------------------------
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_72585ab7602e43719495cb2b1c848535%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_72585ab7602e43719495cb2b1c848535%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_72585ab7602e43719495cb2b1c848535%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_72585ab7602e43719495cb2b1c848535%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.5385583136667%2C%20127.082385189457%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
import json
import requests
import sys
import folium
m = folium.Map(location=[37.5385583136667, 127.082385189457],zoom_start=13) # 광진구 지도

url = "https://dapi.kakao.com/v2/local/search/keyword.json?"
apikey = "ccf9c4dda0eed674c075b234b8d3d390"
loc=['중곡동','능동','구의동','광장동','자양동','화양동','군자동'] # 광진구
#loc=['능동'] # 지도 실험용
for k in loc:
    checker=False
    cnt=0
    pc_list=[]
    place_list=[]
    x_list=[]
    y_list=[]
    phone_list=[]
    id_list=[]
    print('-------------------------------'+str(k)+'----------------------------------')
    print()
    query = "서울 " + k + " pc방"
    for i in range(1,46):
        if checker==True:
            break
        cnt+=1
        r = requests.get( url, params = {'page':str(i), 'query':query}, headers={'Authorization' : 'KakaoAK ' + apikey } ).text
        r = json.loads(str(r))
        match_first = r['documents']
        for j in match_first :
            if j['id'] in id_list:
                checker=True
                break
            if '서울' in j['address_name'] and k in j['address_name'] :
                pc_list.append(j['place_name'])
                place_list.append(j['address_name'])
                x_list.append(j['x'])
                y_list.append(j['y'])
                phone_list.append(j['phone'])
                id_list.append(j['id'])
    for i in range(len(x_list)):
        folium.Marker(location=[y_list[i],x_list[i]],
                      icon=(folium.Icon(icon="gamepad", prefix="fa", color="lightgray")),
                      popup=pc_list[i]).add_to(m)
for k in loc:
    checker=False
    cnt=0
    pc_list=[]
    place_list=[]
    x_list=[]
    y_list=[]
    phone_list=[]
    id_list=[]
    print('-------------------------------'+str(k)+'----------------------------------')
    print()
    query = "서울 " + k +" 학교"
    for i in range(1,46):
        if checker==True:
            break
        cnt+=1
        r = requests.get( url, params = {'page':str(i), 'query':query}, headers={'Authorization' : 'KakaoAK ' + apikey } ).text
        r = json.loads(str(r))
        match_first = r['documents']
        for j in match_first :
            if j['id'] in id_list:
                checker=True
                break
            if '서울' in j['address_name'] and j['category_name'][13:14] in ['중','고']:
                if k in j['address_name'] :
                    pc_list.append(j['place_name'])
                    place_list.append(j['address_name'])
                    x_list.append(j['x'])
                    y_list.append(j['y'])
                    phone_list.append(j['phone'])
                    id_list.append(j['id'])
    for i in range(len(x_list)):
        folium.Marker(location=[y_list[i],x_list[i]],
                      icon=(folium.Icon(icon="male", prefix="fa", color="red")),
                      popup=pc_list[i],max_width='40').add_to(m)
for k in loc:
    checker=False
    cnt=0
    pc_list=[]
    place_list=[]
    x_list=[]
    y_list=[]
    phone_list=[]
    id_list=[]
    print('-------------------------------'+str(k)+'----------------------------------')
    print()
    query = "서울 " + k +" 독서실"
    for i in range(1,46):
        if checker==True:
            break
        cnt+=1
        r = requests.get( url, params = {'page':str(i), 'query':query}, headers={'Authorization' : 'KakaoAK ' + apikey } ).text
        r = json.loads(str(r))
        match_first = r['documents']
        for j in match_first :
            if j['id'] in id_list:
                checker=True
                break
            if '서울' in j['address_name'] and k in j['address_name']:
                pc_list.append(j['place_name'])
                place_list.append(j['address_name'])
                x_list.append(j['x'])
                y_list.append(j['y'])
                phone_list.append(j['phone'])
                id_list.append(j['id'])
    for i in range(len(x_list)):
        folium.Marker(location=[y_list[i],x_list[i]],
                      icon=(folium.Icon(icon="book", prefix="fa", color="lightblue")),
                      popup=pc_list[i],max_width='40').add_to(m)
m
# Out:
# -------------------------------중곡동----------------------------------
#
# -------------------------------능동----------------------------------
#
# -------------------------------구의동----------------------------------
#
# -------------------------------광장동----------------------------------
#
# -------------------------------자양동----------------------------------
#
# -------------------------------화양동----------------------------------
#
# -------------------------------군자동----------------------------------
#
# -------------------------------중곡동----------------------------------
#
# -------------------------------능동----------------------------------
#
# -------------------------------구의동----------------------------------
#
# -------------------------------광장동----------------------------------
#
# -------------------------------자양동----------------------------------
#
# -------------------------------화양동----------------------------------
#
# -------------------------------군자동----------------------------------
#
# -------------------------------중곡동----------------------------------
#
# -------------------------------능동----------------------------------
#
# -------------------------------구의동----------------------------------
#
# -------------------------------광장동----------------------------------
#
# -------------------------------자양동----------------------------------
#
# -------------------------------화양동----------------------------------
#
# -------------------------------군자동----------------------------------
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_82f17fab02104e2bb925dea7ff2d45d0%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_82f17fab02104e2bb925dea7ff2d45d0%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_82f17fab02104e2bb925dea7ff2d45d0%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_82f17fab02104e2bb925dea7ff2d45d0%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.5385583136667%2C%20127.082385189457%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
# 코드 정리
import json
import requests
import folium
m = folium.Map(location=[37.5385583136667, 127.082385189457],zoom_start=13) # 광진구 지도
url = "https://dapi.kakao.com/v2/local/search/keyword.json?"
apikey = "ccf9c4dda0eed674c075b234b8d3d390"
loc=['중곡동','능동','구의동','광장동','자양동','화양동','군자동'] # 광진구
search=[' pc방', ' 학교', ' 독서실']
icon=['gamepad','male','book']
icon_color=['lightgray','red','lightblue']
for final in range(3):
    for k in loc:
        checker=False
        pc_list=[]
        place_list=[]
        x_list=[]
        y_list=[]
        phone_list=[]
        id_list=[]
        print('-------------------------------'+str(k)+str(search[final])+ '----------------------------------') # 진행상태 확인
        print()
        query = "서울 " + k + str(search[final]) # '능동'은 경기도 지역에도 있기 때문
        for i in range(1,46):
            if checker==True:
                break
            r = requests.get( url, params = {'page':str(i), 'query':query}, headers={'Authorization' : 'KakaoAK ' + apikey } ).text
            r = json.loads(str(r))
            match_first = r['documents']
            for j in match_first :
                if j['id'] in id_list:
                    checker=True
                    break
                if final!=1:
                    if '서울' in j['address_name'] and k in j['address_name'] :
                        pc_list.append(j['place_name'])
                        place_list.append(j['address_name'])
                        x_list.append(j['x'])
                        y_list.append(j['y'])
                        phone_list.append(j['phone'])
                        id_list.append(j['id'])
                else:
                    if '서울' in j['address_name'] and j['category_name'][13:14] in ['중','고']: # 초, 대학교(원), 학원 필터링
                        if k in j['address_name'] :
                            pc_list.append(j['place_name'])
                            place_list.append(j['address_name'])
                            x_list.append(j['x'])
                            y_list.append(j['y'])
                            phone_list.append(j['phone'])
                            id_list.append(j['id'])
        for i in range(len(x_list)):
            folium.Marker(location=[y_list[i],x_list[i]],
                          icon=(folium.Icon(icon=icon[final], prefix="fa", color=icon_color[final])),
                          popup=pc_list[i]).add_to(m)
m
# Out:
# -------------------------------중곡동 pc방----------------------------------
#
# -------------------------------능동 pc방----------------------------------
#
# -------------------------------구의동 pc방----------------------------------
#
# -------------------------------광장동 pc방----------------------------------
#
# -------------------------------자양동 pc방----------------------------------
#
# -------------------------------화양동 pc방----------------------------------
#
# -------------------------------군자동 pc방----------------------------------
#
# -------------------------------중곡동 학교----------------------------------
#
# -------------------------------능동 학교----------------------------------
#
# -------------------------------구의동 학교----------------------------------
#
# -------------------------------광장동 학교----------------------------------
#
# -------------------------------자양동 학교----------------------------------
#
# -------------------------------화양동 학교----------------------------------
#
# -------------------------------군자동 학교----------------------------------
#
# -------------------------------중곡동 독서실----------------------------------
#
# -------------------------------능동 독서실----------------------------------
#
# -------------------------------구의동 독서실----------------------------------
#
# -------------------------------광장동 독서실----------------------------------
#
# -------------------------------자양동 독서실----------------------------------
#
# -------------------------------화양동 독서실----------------------------------
#
# -------------------------------군자동 독서실----------------------------------
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_5b38909dae594d91ab16e508511c32f0%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_5b38909dae594d91ab16e508511c32f0%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_5b38909dae594d91ab16e508511c32f0%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_5b38909dae594d91ab16e508511c32f0%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.5385583136667%2C%20127.082385189457%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
# 강남구 시각화
import json
import requests
import folium
#m = folium.Map(location=[37.5385583136667, 127.082385189457],zoom_start=13) # 광진구 지도
m = folium.Map(location=[37.5173319258532, 127.047377408384],zoom_start=13)
url = "https://dapi.kakao.com/v2/local/search/keyword.json?"
apikey = "ccf9c4dda0eed674c075b234b8d3d390"
#loc=['중곡동','능동','구의동','광장동','자양동','화양동','군자동'] # 광진구
loc=['신사동','논현동','압구정동','청담동','삼성동','대치동','역삼동','도곡동','개포동','세곡동','일원동','수서동'] # 강남구
search=[' pc방', ' 학교', ' 독서실']
icon=['gamepad','male','book']
icon_color=['lightgray','red','lightblue']
for final in range(3):
    for k in loc:
        checker=False
        pc_list=[]
        place_list=[]
        x_list=[]
        y_list=[]
        phone_list=[]
        id_list=[]
        print('-------------------------------'+str(k)+str(search[final])+ '----------------------------------') # 진행상태 확인
        print()
        query = "서울 " + k + str(search[final]) # '능동'은 경기도 지역에도 있기 때문
        for i in range(1,46):
            if checker==True:
                break
            r = requests.get( url, params = {'page':str(i), 'query':query}, headers={'Authorization' : 'KakaoAK ' + apikey } ).text
            r = json.loads(str(r))
            match_first = r['documents']
            for j in match_first :
                if j['id'] in id_list:
                    checker=True
                    break
                if final!=1:
                    if '서울' in j['address_name'] and k in j['address_name'] :
                        pc_list.append(j['place_name'])
                        place_list.append(j['address_name'])
                        x_list.append(j['x'])
                        y_list.append(j['y'])
                        phone_list.append(j['phone'])
                        id_list.append(j['id'])
                else:
                    if '서울' in j['address_name'] and j['category_name'][13:14] in ['중','고']: # 초, 대학교(원), 학원 필터링
                        if k in j['address_name'] :
                            pc_list.append(j['place_name'])
                            place_list.append(j['address_name'])
                            x_list.append(j['x'])
                            y_list.append(j['y'])
                            phone_list.append(j['phone'])
                            id_list.append(j['id'])
        for i in range(len(x_list)):
            folium.Marker(location=[y_list[i],x_list[i]],
                          icon=(folium.Icon(icon=icon[final], prefix="fa", color=icon_color[final])),
                          popup=pc_list[i]).add_to(m)
m
# Out:
# -------------------------------신사동 pc방----------------------------------
#
# -------------------------------논현동 pc방----------------------------------
#
# -------------------------------압구정동 pc방----------------------------------
#
# -------------------------------청담동 pc방----------------------------------
#
# -------------------------------삼성동 pc방----------------------------------
#
# -------------------------------대치동 pc방----------------------------------
#
# -------------------------------역삼동 pc방----------------------------------
#
# -------------------------------도곡동 pc방----------------------------------
#
# -------------------------------개포동 pc방----------------------------------
#
# -------------------------------세곡동 pc방----------------------------------
#
# -------------------------------일원동 pc방----------------------------------
#
# -------------------------------수서동 pc방----------------------------------
#
# -------------------------------신사동 학교----------------------------------
#
# -------------------------------논현동 학교----------------------------------
#
# -------------------------------압구정동 학교----------------------------------
#
# -------------------------------청담동 학교----------------------------------
#
# -------------------------------삼성동 학교----------------------------------
#
# -------------------------------대치동 학교----------------------------------
#
# -------------------------------역삼동 학교----------------------------------
#
# -------------------------------도곡동 학교----------------------------------
#
# -------------------------------개포동 학교----------------------------------
#
# -------------------------------세곡동 학교----------------------------------
#
# -------------------------------일원동 학교----------------------------------
#
# -------------------------------수서동 학교----------------------------------
#
# -------------------------------신사동 독서실----------------------------------
#
# -------------------------------논현동 독서실----------------------------------
#
# -------------------------------압구정동 독서실----------------------------------
#
# -------------------------------청담동 독서실----------------------------------
#
# -------------------------------삼성동 독서실----------------------------------
#
# -------------------------------대치동 독서실----------------------------------
#
# -------------------------------역삼동 독서실----------------------------------
#
# -------------------------------도곡동 독서실----------------------------------
#
# -------------------------------개포동 독서실----------------------------------
#
# -------------------------------세곡동 독서실----------------------------------
#
# -------------------------------일원동 독서실----------------------------------
#
# -------------------------------수서동 독서실----------------------------------
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_a5b5219245f5405290996e5bb31a7736%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_a5b5219245f5405290996e5bb31a7736%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_a5b5219245f5405290996e5bb31a7736%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_a5b5219245f5405290996e5bb31a7736%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.5173319258532%2C%20127.047377408384%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
# 코드 정리
import json
import requests
import folium
m = folium.Map(location=[37.5385583136667, 127.082385189457],zoom_start=13) # 광진구 지도
url = "https://dapi.kakao.com/v2/local/search/keyword.json?"
apikey = "ccf9c4dda0eed674c075b234b8d3d390"
loc=['중곡동','능동','구의동','광장동','자양동','화양동','군자동'] # 광진구
search=[' pc방', ' 학교', ' 독서실']
icon=['gamepad','male','book']
icon_color=['lightgray','red','lightblue']
for final in range(3):
    for k in loc:
        checker=False
        pc_list=[]
        place_list=[]
        x_list=[]
        y_list=[]
        phone_list=[]
        id_list=[]
        print('-------------------------------'+str(k)+str(search[final])+ '----------------------------------') # 진행상태 확인
        print()
        query = "서울 " + k + str(search[final]) # '능동'은 경기도 지역에도 있기 때문
        for i in range(1,46):
            if checker==True:
                break
            r = requests.get( url, params = {'page':str(i), 'query':query}, headers={'Authorization' : 'KakaoAK ' + apikey } ).text
            r = json.loads(str(r))
            match_first = r['documents']
            for j in match_first :
                if j['id'] in id_list:
                    checker=True
                    break
                if final!=1:
                    if '서울' in j['address_name'] and k in j['address_name'] :
                        pc_list.append(j['place_name'])
                        place_list.append(j['address_name'])
                        x_list.append(j['x'])
                        y_list.append(j['y'])
                        phone_list.append(j['phone'])
                        id_list.append(j['id'])
                else:
                    if '서울' in j['address_name'] and j['category_name'][13:14] in ['중','고']: # 초, 대학교(원), 학원 필터링
                        if k in j['address_name'] :
                            pc_list.append(j['place_name'])
                            place_list.append(j['address_name'])
                            x_list.append(j['x'])
                            y_list.append(j['y'])
                            phone_list.append(j['phone'])
                            id_list.append(j['id'])
        for i in range(len(x_list)):
            folium.Marker(location=[y_list[i],x_list[i]],
                          icon=(folium.Icon(icon=icon[final], prefix="fa", color=icon_color[final])),
                          popup=pc_list[i]).add_to(m)
loc=['신사동','논현동','압구정동','청담동','삼성동','대치동','역삼동','도곡동','개포동','세곡동','일원동','수서동'] # 강남구
search=[' pc방', ' 학교', ' 독서실']
icon=['gamepad','male','book']
icon_color=['lightgray','red','lightblue']
for final in range(3):
    for k in loc:
        checker=False
        pc_list=[]
        place_list=[]
        x_list=[]
        y_list=[]
        phone_list=[]
        id_list=[]
        print('-------------------------------'+str(k)+str(search[final])+ '----------------------------------') # 진행상태 확인
        print()
        query = "서울 " + k + str(search[final]) # '능동'은 경기도 지역에도 있기 때문
        for i in range(1,46):
            if checker==True:
                break
            r = requests.get( url, params = {'page':str(i), 'query':query}, headers={'Authorization' : 'KakaoAK ' + apikey } ).text
            r = json.loads(str(r))
            match_first = r['documents']
            for j in match_first :
                if j['id'] in id_list:
                    checker=True
                    break
                if final!=1:
                    if '서울' in j['address_name'] and k in j['address_name'] :
                        pc_list.append(j['place_name'])
                        place_list.append(j['address_name'])
                        x_list.append(j['x'])
                        y_list.append(j['y'])
                        phone_list.append(j['phone'])
                        id_list.append(j['id'])
                else:
                    if '서울' in j['address_name'] and j['category_name'][13:14] in ['중','고']: # 초, 대학교(원), 학원 필터링
                        if k in j['address_name'] :
                            pc_list.append(j['place_name'])
                            place_list.append(j['address_name'])
                            x_list.append(j['x'])
                            y_list.append(j['y'])
                            phone_list.append(j['phone'])
                            id_list.append(j['id'])
        for i in range(len(x_list)):
            folium.Marker(location=[y_list[i],x_list[i]],
                          icon=(folium.Icon(icon=icon[final], prefix="fa", color=icon_color[final])),
                          popup=pc_list[i]).add_to(m)
m
# Out:
# -------------------------------중곡동 pc방----------------------------------
#
# -------------------------------능동 pc방----------------------------------
#
# -------------------------------구의동 pc방----------------------------------
#
# -------------------------------광장동 pc방----------------------------------
#
# -------------------------------자양동 pc방----------------------------------
#
# -------------------------------화양동 pc방----------------------------------
#
# -------------------------------군자동 pc방----------------------------------
#
# -------------------------------중곡동 학교----------------------------------
#
# -------------------------------능동 학교----------------------------------
#
# -------------------------------구의동 학교----------------------------------
#
# -------------------------------광장동 학교----------------------------------
#
# -------------------------------자양동 학교----------------------------------
#
# -------------------------------화양동 학교----------------------------------
#
# -------------------------------군자동 학교----------------------------------
#
# -------------------------------중곡동 독서실----------------------------------
#
# -------------------------------능동 독서실----------------------------------
#
# -------------------------------구의동 독서실----------------------------------
#
# -------------------------------광장동 독서실----------------------------------
#
# -------------------------------자양동 독서실----------------------------------
#
# -------------------------------화양동 독서실----------------------------------
#
# -------------------------------군자동 독서실----------------------------------
#
# -------------------------------신사동 pc방----------------------------------
#
# -------------------------------논현동 pc방----------------------------------
#
# -------------------------------압구정동 pc방----------------------------------
#
# -------------------------------청담동 pc방----------------------------------
#
# -------------------------------삼성동 pc방----------------------------------
#
# -------------------------------대치동 pc방----------------------------------
#
# -------------------------------역삼동 pc방----------------------------------
#
# -------------------------------도곡동 pc방----------------------------------
#
# -------------------------------개포동 pc방----------------------------------
#
# -------------------------------세곡동 pc방----------------------------------
#
# -------------------------------일원동 pc방----------------------------------
#
# -------------------------------수서동 pc방----------------------------------
#
# -------------------------------신사동 학교----------------------------------
#
# -------------------------------논현동 학교----------------------------------
#
# -------------------------------압구정동 학교----------------------------------
#
# -------------------------------청담동 학교----------------------------------
#
# -------------------------------삼성동 학교----------------------------------
#
# -------------------------------대치동 학교----------------------------------
#
# -------------------------------역삼동 학교----------------------------------
#
# -------------------------------도곡동 학교----------------------------------
#
# -------------------------------개포동 학교----------------------------------
#
# -------------------------------세곡동 학교----------------------------------
#
# -------------------------------일원동 학교----------------------------------
#
# -------------------------------수서동 학교----------------------------------
#
# -------------------------------신사동 독서실----------------------------------
#
# -------------------------------논현동 독서실----------------------------------
#
# -------------------------------압구정동 독서실----------------------------------
#
# -------------------------------청담동 독서실----------------------------------
#
# -------------------------------삼성동 독서실----------------------------------
#
# -------------------------------대치동 독서실----------------------------------
#
# -------------------------------역삼동 독서실----------------------------------
#
# -------------------------------도곡동 독서실----------------------------------
#
# -------------------------------개포동 독서실----------------------------------
#
# -------------------------------세곡동 독서실----------------------------------
#
# -------------------------------일원동 독서실----------------------------------
#
# -------------------------------수서동 독서실----------------------------------
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_b074180476964f059b7e53e9ea61c1a2%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_b074180476964f059b7e53e9ea61c1a2%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_b074180476964f059b7e53e9ea61c1a2%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_b074180476964f059b7e53e9ea61c1a2%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.5385583136667%2C%20127.082385189457%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
m.save('kakaomap_GwangJin_GangNam.html')
